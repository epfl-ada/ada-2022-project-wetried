# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
timeseries = pd.read_json("aggregated_timeseries.json.gz")

# %% [markdown]
# # Timeseries

# %% [markdown]
# ## Splitting the data into different dataframes

# %%
timeseries.head()
# Out:
#                                                      ja.m  \
# len                                               1197788
# sum     {'2018-01-01 00:00:00': 22328288, '2018-01-02 ...
# covid   {'len': 30, 'sum': {'2018-01-01 00:00:00': 55,...
# topics  {'Culture.Biography.Biography*': {'len': 14904...
#
#                                                        it  \
# len                                               1594039
# sum     {'2018-01-01 00:00:00': 3338750, '2018-01-02 0...
# covid   {'len': 33, 'sum': {'2018-01-01 00:00:00': 50,...
# topics  {'Culture.Biography.Biography*': {'len': 29427...
#
#                                                      da.m  \
# len                                                256451
# sum     {'2018-01-01 00:00:00': 765123, '2018-01-02 00...
# covid   {'len': 4, 'sum': {'2018-01-01 00:00:00': 0, '...
# topics  {'Culture.Biography.Biography*': {'len': 57720...
#
#                                                        tr  \
# len                                                346007
# sum     {'2018-01-01 00:00:00': 407629, '2018-01-02 00...
# covid   {'len': 64, 'sum': {'2018-01-01 00:00:00': 1, ...
# topics  {'Culture.Biography.Biography*': {'len': 70443...
#
#                                                      no.m  \
# len                                                516838
# sum     {'2018-01-01 00:00:00': 715031, '2018-01-02 00...
# covid   {'len': 10, 'sum': {'2018-01-01 00:00:00': 7, ...
# topics  {'Culture.Biography.Biography*': {'len': 11603...
#
#                                                        en  \
# len                                               6047509
# sum     {'2018-01-01 00:00:00': 86763830, '2018-01-02 ...
# covid   {'len': 306, 'sum': {'2018-01-01 00:00:00': 57...
# topics  {'Culture.Biography.Biography*': {'len': 14038...
#
#                                                        sr  \
# len                                                632128
# sum     {'2018-01-01 00:00:00': 192409, '2018-01-02 00...
# covid   {'len': 9, 'sum': {'2018-01-01 00:00:00': 6, '...
# topics  {'Culture.Biography.Biography*': {'len': 37718...
#
#                                                      tr.m  \
# len                                                345790
# sum     {'2018-01-01 00:00:00': 493684, '2018-01-02 00...
# covid   {'len': 64, 'sum': {'2018-01-01 00:00:00': 3, ...
# topics  {'Culture.Biography.Biography*': {'len': 70434...
#
#                                                      en.m  \
# len                                               6045654
# sum     {'2018-01-01 00:00:00': 135822131, '2018-01-02...
# covid   {'len': 306, 'sum': {'2018-01-01 00:00:00': 91...
# topics  {'Culture.Biography.Biography*': {'len': 14038...
#
#                                                        no  ...  \
# len                                                531478  ...
# sum     {'2018-01-01 00:00:00': 224417, '2018-01-02 00...  ...
# covid   {'len': 10, 'sum': {'2018-01-01 00:00:00': 2, ...  ...
# topics  {'Culture.Biography.Biography*': {'len': 11804...  ...
#
#                                                      ko.m  \
# len                                                489181
# sum     {'2018-01-01 00:00:00': 1484496, '2018-01-02 0...
# covid   {'len': 113, 'sum': {'2018-01-01 00:00:00': 6,...
# topics  {'Culture.Biography.Biography*': {'len': 75406...
#
#                                                      fi.m  \
# len                                                480638
# sum     {'2018-01-01 00:00:00': 1319053, '2018-01-02 0...
# covid   {'len': 9, 'sum': {'2018-01-01 00:00:00': 0, '...
# topics  {'Culture.Biography.Biography*': {'len': 10422...
#
#                                                      sr.m  \
# len                                                396063
# sum     {'2018-01-01 00:00:00': 451383, '2018-01-02 00...
# covid   {'len': 9, 'sum': {'2018-01-01 00:00:00': 11, ...
# topics  {'Culture.Biography.Biography*': {'len': 37580...
#
#                                                        ja  \
# len                                               1197856
# sum     {'2018-01-01 00:00:00': 7828155, '2018-01-02 0...
# covid   {'len': 30, 'sum': {'2018-01-01 00:00:00': 26,...
# topics  {'Culture.Biography.Biography*': {'len': 14904...
#
#                                                        fr  \
# len                                               2195949
# sum     {'2018-01-01 00:00:00': 6441009, '2018-01-02 0...
# covid   {'len': 16, 'sum': {'2018-01-01 00:00:00': 62,...
# topics  {'Culture.Biography.Biography*': {'len': 38258...
#
#                                                        fi  \
# len                                                481854
# sum     {'2018-01-01 00:00:00': 523135, '2018-01-02 00...
# covid   {'len': 9, 'sum': {'2018-01-01 00:00:00': 2, '...
# topics  {'Culture.Biography.Biography*': {'len': 10444...
#
#                                                        ca  \
# len                                                642031
# sum     {'2018-01-01 00:00:00': 111910, '2018-01-02 00...
# covid   {'len': 49, 'sum': {'2018-01-01 00:00:00': 6, ...
# topics  {'Culture.Biography.Biography*': {'len': 10175...
#
#                                                      it.m  \
# len                                               1588312
# sum     {'2018-01-01 00:00:00': 12856884, '2018-01-02 ...
# covid   {'len': 33, 'sum': {'2018-01-01 00:00:00': 139...
# topics  {'Culture.Biography.Biography*': {'len': 29422...
#
#                                                      sv.m  \
# len                                               1959446
# sum     {'2018-01-01 00:00:00': 2383474, '2018-01-02 0...
# covid   {'len': 8, 'sum': {'2018-01-01 00:00:00': 19, ...
# topics  {'Culture.Biography.Biography*': {'len': 14668...
#
#                                                        ko
# len                                                490314
# sum     {'2018-01-01 00:00:00': 819174, '2018-01-02 00...
# covid   {'len': 113, 'sum': {'2018-01-01 00:00:00': 3,...
# topics  {'Culture.Biography.Biography*': {'len': 75498...
#
# [4 rows x 28 columns]

# %%
timeseries.columns
# Out:
# Index(['ja.m', 'it', 'da.m', 'tr', 'no.m', 'en', 'sr', 'tr.m', 'en.m', 'no',
#        'sv', 'nl.m', 'nl', 'da', 'de', 'fr.m', 'ca.m', 'de.m', 'ko.m', 'fi.m',
#        'sr.m', 'ja', 'fr', 'fi', 'ca', 'it.m', 'sv.m', 'ko'],
#       dtype='object')

# %% [markdown]
# Correspondence:
# - ja -> Japanese
# - it -> Italian
# - da -> Danish
# - tr -> ?
# - no -> Norwegian
# - en -> English
# - sr -> Serbian
# - sv -> Swedish
# - nl -> Dutch
# - de -> German
# - fr -> French
# - ca -> ?
# - ko -> Korean
# - fi -> Finnish
#
# Not sure about the "?" ones. According to https://www.loc.gov/standards/iso639-2/php/langcodes-search.php, these correspond respectively to Turkish and Catalan.

# %% [markdown]
# ### Total sum of views, views of articles related to Covid

# %%
timeseries_total_sum_dict = {}
timeseries_covid_len_dict = {}
timeseries_covid_sum_dict = {}
timeseries_covid_percent_dict = {}
for cn in timeseries.columns:
    timeseries_total_sum_dict[cn] = timeseries[cn]['sum']
    timeseries_covid_len_dict[cn] = timeseries[cn]['covid']['len']
    timeseries_covid_sum_dict[cn] = timeseries[cn]['covid']['sum']
    timeseries_covid_percent_dict[cn] = timeseries[cn]['covid']['percent']

# %%
sum_data_df = pd.DataFrame.from_dict(timeseries_total_sum_dict, orient = 'index').T
## There is more data in the covid data
covid_len_data_df = pd.DataFrame.from_dict(timeseries_covid_len_dict, orient = 'index', columns = ['len']).T
covid_sum_data_df = pd.DataFrame.from_dict(timeseries_covid_sum_dict, orient = 'index').T
covid_percent_data_df = pd.DataFrame.from_dict(timeseries_covid_percent_dict, orient = 'index').T

# %%
index_without_time = [x[:10] for x in covid_sum_data_df.index]
sum_data_df.index = covid_sum_data_df.index = covid_percent_data_df.index = pd.to_datetime(index_without_time)
sum_data_df['dates'] = covid_sum_data_df['dates'] = covid_percent_data_df['dates'] = sum_data_df.index
new_column_order = [sum_data_df.columns[-1]] + list(sum_data_df.columns[-2::-1])
sum_data_df = sum_data_df[new_column_order]
covid_sum_data_df = covid_sum_data_df[new_column_order]
covid_percent_data_df = covid_percent_data_df[new_column_order]
#.columns = covid_sum_data_df.columns = covid_percent_data_df.columns = [sum_data_df.columns[-1]] + list(sum_data_df.columns[-2::-1])

# %%
sum_data_df.head()
# Out:
#                 dates       ko     sv.m      it.m      ca      fi        fr  \
# 2018-01-01 2018-01-01   819174  2383474  12856884  111910  523135   6441009
# 2018-01-02 2018-01-02   959239  1873096  12887390  198405  648344   9079323
# 2018-01-03 2018-01-03  1037688  1863012  12859488  188728  644605   9746428
# 2018-01-04 2018-01-04   956653  1810874  12359845  203167  643311  10034517
# 2018-01-05 2018-01-05   955955  2191670  12107559  168126  614471   9511358
#
#                   ja    sr.m     fi.m  ...      no       en.m    tr.m      sr  \
# 2018-01-01   7828155  451383  1319053  ...  224417  135822131  493684  192409
# 2018-01-02   8759385  462824  1094280  ...  374771  127087359  483443  253653
# 2018-01-03   9996156  404880  1022615  ...  459743  116606137  471814  272278
# 2018-01-04  11976989  391631  1001547  ...  479999  115650878  462107  273699
# 2018-01-05  12746833  380159  1012466  ...  444863  116127950  485637  257239
#
#                    en    no.m      tr    da.m       it      ja.m
# 2018-01-01   86763830  715031  407629  765123  3338750  22328288
# 2018-01-02  112245349  536506  426791  443384  5428428  22278953
# 2018-01-03  121868290  552379  468642  415545  5640812  23632758
# 2018-01-04  112888840  528468  462860  416943  5794860  21893587
# 2018-01-05  109213987  600262  407226  455392  5475376  20734837
#
# [5 rows x 29 columns]

# %%
covid_sum_data_df.head()
# Out:
#                 dates  ko  sv.m  it.m  ca  fi   fr   ja  sr.m  fi.m  ...  no  \
# 2018-01-01 2018-01-01   3    19   139   6   2   62   26    11     0  ...   2
# 2018-01-02 2018-01-02  20    12   187   6   2   91   42    20     0  ...   4
# 2018-01-03 2018-01-03  20    13   162   9   2  109   53    15     8  ...   3
# 2018-01-04 2018-01-04  16    14   180  10   3  107  114    30     0  ...   1
# 2018-01-05 2018-01-05  20    11   127   4   0  113  134    33     0  ...   4
#
#             en.m  tr.m  sr    en  no.m  tr  da.m   it  ja.m
# 2018-01-01   911     3   6   575     7   1     0   50    55
# 2018-01-02  1006     2  13  1081     5   3     2  103    55
# 2018-01-03   919     2  11  1265     2   6     1  130    51
# 2018-01-04  1026     9   6  1167     2   1     0  112    46
# 2018-01-05   978     2  13  1054     2   0     0  119    70
#
# [5 rows x 29 columns]

# %%
covid_percent_data_df.head()
# Out:
#                 dates        ko      sv.m      it.m        ca        fi  \
# 2018-01-01 2018-01-01  0.000004  0.000008  0.000011  0.000054  0.000004
# 2018-01-02 2018-01-02  0.000021  0.000006  0.000015  0.000030  0.000003
# 2018-01-03 2018-01-03  0.000019  0.000007  0.000013  0.000048  0.000003
# 2018-01-04 2018-01-04  0.000017  0.000008  0.000015  0.000049  0.000005
# 2018-01-05 2018-01-05  0.000021  0.000005  0.000010  0.000024  0.000000
#
#                   fr        ja      sr.m      fi.m  ...        no      en.m  \
# 2018-01-01  0.000010  0.000003  0.000024  0.000000  ...  0.000009  0.000007
# 2018-01-02  0.000010  0.000005  0.000043  0.000000  ...  0.000011  0.000008
# 2018-01-03  0.000011  0.000005  0.000037  0.000008  ...  0.000007  0.000008
# 2018-01-04  0.000011  0.000010  0.000077  0.000000  ...  0.000002  0.000009
# 2018-01-05  0.000012  0.000011  0.000087  0.000000  ...  0.000009  0.000008
#
#                 tr.m        sr        en      no.m        tr      da.m  \
# 2018-01-01  0.000006  0.000031  0.000007  0.000010  0.000002  0.000000
# 2018-01-02  0.000004  0.000051  0.000010  0.000009  0.000007  0.000005
# 2018-01-03  0.000004  0.000040  0.000010  0.000004  0.000013  0.000002
# 2018-01-04  0.000019  0.000022  0.000010  0.000004  0.000002  0.000000
# 2018-01-05  0.000004  0.000051  0.000010  0.000003  0.000000  0.000000
#
#                   it      ja.m
# 2018-01-01  0.000015  0.000002
# 2018-01-02  0.000019  0.000002
# 2018-01-03  0.000023  0.000002
# 2018-01-04  0.000019  0.000002
# 2018-01-05  0.000022  0.000003
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Topics data

# %%
country_to_topics = {}
for cn in timeseries.columns:
    country_to_topics[cn] = timeseries[cn]['topics']
topics_df = pd.DataFrame.from_dict(country_to_topics, orient = 'index')

# %%
topics_df.head(3)
# Out:
#                            Culture.Biography.Biography*  \
# ja.m  {'len': 149042, 'sum': {'2018-01-01 00:00:00':...
# it    {'len': 294279, 'sum': {'2018-01-01 00:00:00':...
# da.m  {'len': 57720, 'sum': {'2018-01-01 00:00:00': ...
#
#                                 Culture.Biography.Women  \
# ja.m  {'len': 22518, 'sum': {'2018-01-01 00:00:00': ...
# it    {'len': 51008, 'sum': {'2018-01-01 00:00:00': ...
# da.m  {'len': 8975, 'sum': {'2018-01-01 00:00:00': 7...
#
#                                  Culture.Food and drink  \
# ja.m  {'len': 5759, 'sum': {'2018-01-01 00:00:00': 3...
# it    {'len': 5630, 'sum': {'2018-01-01 00:00:00': 3...
# da.m  {'len': 2241, 'sum': {'2018-01-01 00:00:00': 1...
#
#                                Culture.Internet culture  \
# ja.m  {'len': 10571, 'sum': {'2018-01-01 00:00:00': ...
# it    {'len': 13413, 'sum': {'2018-01-01 00:00:00': ...
# da.m  {'len': 2251, 'sum': {'2018-01-01 00:00:00': 4...
#
#                                     Culture.Linguistics  \
# ja.m  {'len': 6008, 'sum': {'2018-01-01 00:00:00': 1...
# it    {'len': 6919, 'sum': {'2018-01-01 00:00:00': 2...
# da.m  {'len': 1870, 'sum': {'2018-01-01 00:00:00': 4...
#
#                                      Culture.Literature  \
# ja.m  {'len': 24204, 'sum': {'2018-01-01 00:00:00': ...
# it    {'len': 35273, 'sum': {'2018-01-01 00:00:00': ...
# da.m  {'len': 5726, 'sum': {'2018-01-01 00:00:00': 2...
#
#                                     Culture.Media.Books  \
# ja.m  {'len': 3833, 'sum': {'2018-01-01 00:00:00': 9...
# it    {'len': 9402, 'sum': {'2018-01-01 00:00:00': 5...
# da.m  {'len': 1365, 'sum': {'2018-01-01 00:00:00': 8...
#
#                             Culture.Media.Entertainment  \
# ja.m  {'len': 6047, 'sum': {'2018-01-01 00:00:00': 2...
# it    {'len': 8474, 'sum': {'2018-01-01 00:00:00': 8...
# da.m  {'len': 1950, 'sum': {'2018-01-01 00:00:00': 1...
#
#                                     Culture.Media.Films  \
# ja.m  {'len': 20227, 'sum': {'2018-01-01 00:00:00': ...
# it    {'len': 48132, 'sum': {'2018-01-01 00:00:00': ...
# da.m  {'len': 5027, 'sum': {'2018-01-01 00:00:00': 4...
#
#                                    Culture.Media.Media*  ...  \
# ja.m  {'len': 93263, 'sum': {'2018-01-01 00:00:00': ...  ...
# it    {'len': 199947, 'sum': {'2018-01-01 00:00:00':...  ...
# da.m  {'len': 29520, 'sum': {'2018-01-01 00:00:00': ...  ...
#
#                                          STEM.Computing  \
# ja.m  {'len': 10688, 'sum': {'2018-01-01 00:00:00': ...
# it    {'len': 9839, 'sum': {'2018-01-01 00:00:00': 4...
# da.m  {'len': 2063, 'sum': {'2018-01-01 00:00:00': 2...
#
#                              STEM.Earth and environment  \
# ja.m  {'len': 6338, 'sum': {'2018-01-01 00:00:00': 7...
# it    {'len': 11672, 'sum': {'2018-01-01 00:00:00': ...
# da.m  {'len': 2083, 'sum': {'2018-01-01 00:00:00': 3...
#
#                                        STEM.Engineering  \
# ja.m  {'len': 14036, 'sum': {'2018-01-01 00:00:00': ...
# it    {'len': 15216, 'sum': {'2018-01-01 00:00:00': ...
# da.m  {'len': 3591, 'sum': {'2018-01-01 00:00:00': 6...
#
#                            STEM.Libraries & Information  \
# ja.m  {'len': 763, 'sum': {'2018-01-01 00:00:00': 10...
# it    {'len': 1200, 'sum': {'2018-01-01 00:00:00': 7...
# da.m  {'len': 371, 'sum': {'2018-01-01 00:00:00': 22...
#
#                                        STEM.Mathematics  \
# ja.m  {'len': 4354, 'sum': {'2018-01-01 00:00:00': 4...
# it    {'len': 3954, 'sum': {'2018-01-01 00:00:00': 1...
# da.m  {'len': 852, 'sum': {'2018-01-01 00:00:00': 17...
#
#                                  STEM.Medicine & Health  \
# ja.m  {'len': 10354, 'sum': {'2018-01-01 00:00:00': ...
# it    {'len': 13576, 'sum': {'2018-01-01 00:00:00': ...
# da.m  {'len': 3355, 'sum': {'2018-01-01 00:00:00': 1...
#
#                                            STEM.Physics  \
# ja.m  {'len': 6204, 'sum': {'2018-01-01 00:00:00': 7...
# it    {'len': 6213, 'sum': {'2018-01-01 00:00:00': 3...
# da.m  {'len': 1853, 'sum': {'2018-01-01 00:00:00': 3...
#
#                                              STEM.STEM*  \
# ja.m  {'len': 97050, 'sum': {'2018-01-01 00:00:00': ...
# it    {'len': 123609, 'sum': {'2018-01-01 00:00:00':...
# da.m  {'len': 29111, 'sum': {'2018-01-01 00:00:00': ...
#
#                                              STEM.Space  \
# ja.m  {'len': 9338, 'sum': {'2018-01-01 00:00:00': 6...
# it    {'len': 13742, 'sum': {'2018-01-01 00:00:00': ...
# da.m  {'len': 2107, 'sum': {'2018-01-01 00:00:00': 2...
#
#                                         STEM.Technology
# ja.m  {'len': 15411, 'sum': {'2018-01-01 00:00:00': ...
# it    {'len': 15380, 'sum': {'2018-01-01 00:00:00': ...
# da.m  {'len': 4158, 'sum': {'2018-01-01 00:00:00': 7...
#
# [3 rows x 64 columns]

# %% [markdown]
# ### Checking for missing data

# %%
sum_data_df.isnull().any().any(), covid_sum_data_df.isnull().any().any(), covid_percent_data_df.isnull().any().any()
# Out:
# (False, False, True)

# %% [markdown]
# There appears to be some missing data in the percentage dataframe; let's check by language where that missing data is reported.

# %%
missing_data_language = covid_percent_data_df.isnull().any(axis = 0)
missing_data_language[missing_data_language]
# Out:
# sv    True
# dtype: bool

# %% [markdown]
# Looking at the paper, this corresponds to Swedish. Let's check in the other dataframes how that missing data manifests itself.

# %%
sum_data_df.loc[:,['dates','sv']]
# Out:
#                 dates      sv
# 2018-01-01 2018-01-01       0
# 2018-01-02 2018-01-02       0
# 2018-01-03 2018-01-03       0
# 2018-01-04 2018-01-04       0
# 2018-01-05 2018-01-05       0
# ...               ...     ...
# 2020-07-27 2020-07-27  622918
# 2020-07-28 2020-07-28  645601
# 2020-07-29 2020-07-29  639190
# 2020-07-30 2020-07-30  613870
# 2020-07-31 2020-07-31  549610
#
# [943 rows x 2 columns]

# %%
covid_sum_data_df.loc[:,['dates', 'sv']]
# Out:
#                 dates   sv
# 2018-01-01 2018-01-01    0
# 2018-01-02 2018-01-02    0
# 2018-01-03 2018-01-03    0
# 2018-01-04 2018-01-04    0
# 2018-01-05 2018-01-05    0
# ...               ...  ...
# 2020-07-27 2020-07-27  245
# 2020-07-28 2020-07-28  291
# 2020-07-29 2020-07-29  296
# 2020-07-30 2020-07-30  267
# 2020-07-31 2020-07-31  252
#
# [943 rows x 2 columns]

# %% [markdown]
# In both dataframes, the missing data corresponds to 0 values for the dates. The NaN values thus correspond to a division by 0. Let us now check the first date where we get data for Swedish.

# %%
swedish_mask = sum_data_df.loc[:,'sv'] > 0

# %%
sum_data_df.loc[:,'sv'][swedish_mask]
# Out:
# 2019-01-01    607516
# 2019-01-02    821962
# 2019-01-03    872335
# 2019-01-04    854304
# 2019-01-05    775861
#                ...
# 2020-07-27    622918
# 2020-07-28    645601
# 2020-07-29    639190
# 2020-07-30    613870
# 2020-07-31    549610
# Name: sv, Length: 578, dtype: int64

# %%
covid_sum_data_df.loc[:,'sv'][swedish_mask]
# Out:
# 2019-01-01      1
# 2019-01-02      1
# 2019-01-03      3
# 2019-01-04      5
# 2019-01-05      2
#              ...
# 2020-07-27    245
# 2020-07-28    291
# 2020-07-29    296
# 2020-07-30    267
# 2020-07-31    252
# Name: sv, Length: 578, dtype: int64

# %% [markdown]
# From what we can see, it appears that all the Swedish data from 2018 is missing; we will need to take that into consideration when doing our analysis.

# %% [markdown]
# # Apple mobility

# %%
apple_mobility = pd.read_csv("applemobilitytrends-2020-04-20.csv.gz")
#apple_mobility = apple_mobility.T
apple_mobility.head()
# Out:
#          geo_type     region transportation_type  2020-01-13  2020-01-14  \
# 0  country/region    Albania             driving         100       95.30
# 1  country/region    Albania             walking         100      100.68
# 2  country/region  Argentina             driving         100       97.07
# 3  country/region  Argentina             walking         100       95.11
# 4  country/region  Australia             driving         100      102.98
#
#    2020-01-15  2020-01-16  2020-01-17  2020-01-18  2020-01-19  ...  \
# 0      101.43       97.20      103.55      112.67      104.83  ...
# 1       98.93       98.46      100.85      100.13       82.13  ...
# 2      102.45      111.21      118.45      124.01       95.44  ...
# 3      101.37      112.67      116.72      114.14       84.54  ...
# 4      104.21      108.63      109.08       89.00       99.35  ...
#
#    2020-04-11  2020-04-12  2020-04-13  2020-04-14  2020-04-15  2020-04-16  \
# 0       25.47       24.89       32.64       31.43       30.67       30.00
# 1       27.63       29.59       35.52       38.08       35.48       39.15
# 2       19.40       12.89       21.10       22.29       23.55       24.40
# 3       15.75       10.45       16.35       16.66       17.42       18.18
# 4       26.95       31.72       53.14       55.91       56.56       58.77
#
#    2020-04-17  2020-04-18  2020-04-19  2020-04-20
# 0       29.26       22.94       24.55       31.51
# 1       34.58       27.76       27.93       36.72
# 2       27.17       23.19       14.54       26.67
# 3       18.80       17.03       10.59       18.44
# 4       47.51       36.90       53.34       56.93
#
# [5 rows x 102 columns]

# %%
apple_mobility.transportation_type.unique()
# Out:
# array(['driving', 'walking', 'transit'], dtype=object)

# %%
apple_mobility_walking = apple_mobility[apple_mobility.transportation_type == 'walking']
apple_mobility_driving = apple_mobility[apple_mobility.transportation_type == 'driving']
apple_mobility_transit = apple_mobility[apple_mobility.transportation_type == 'transit']

# %%
apple_mobility_walking_albania = apple_mobility_walking[apple_mobility_walking['region'] == 'Albania']

# %%
timeseries_walking_albanian_data = apple_mobility_walking_albania[apple_mobility_walking_albania.columns[3:]]

# %%
timeseries_walking_albanian_data.columns = pd.to_datetime(timeseries_walking_albanian_data.columns)

# %%
#timeseries_albanian_data = timeseries_albanian_data.T

# %%
timeseries_walking_albanian_data
# Out:
#    2020-01-13  2020-01-14  2020-01-15  2020-01-16  2020-01-17  2020-01-18  \
# 1         100      100.68       98.93       98.46      100.85      100.13
#
#    2020-01-19  2020-01-20  2020-01-21  2020-01-22  ...  2020-04-11  \
# 1       82.13       95.65       97.78       95.39  ...       27.63
#
#    2020-04-12  2020-04-13  2020-04-14  2020-04-15  2020-04-16  2020-04-17  \
# 1       29.59       35.52       38.08       35.48       39.15       34.58
#
#    2020-04-18  2020-04-19  2020-04-20
# 1       27.76       27.93       36.72
#
# [1 rows x 99 columns]

# %%
fig = plt.figure()
g = sns.lineplot( x = timeseries_walking_albanian_data.columns, y = timeseries_walking_albanian_data.iloc[0])
g.xaxis.set_major_locator(ticker.LinearLocator(7))
plt.xticks(fontsize=8)
g.set(xlabel='Dates', ylabel='Percentage')
g.set(title='Albanian walking')
# Out:
# [Text(0.5, 1.0, 'Albanian walking')]

# %% [markdown]
# # Global mobility

# %%
global_mobility_report = pd.read_csv("Global_Mobility_Report.csv.gz")
global_mobility_report
# Out:
# D:\Miniconda\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         country_region_code        country_region       sub_region_1  \
# 0                        AE  United Arab Emirates                NaN
# 1                        AE  United Arab Emirates                NaN
# 2                        AE  United Arab Emirates                NaN
# 3                        AE  United Arab Emirates                NaN
# 4                        AE  United Arab Emirates                NaN
# ...                     ...                   ...                ...
# 2111407                  ZW              Zimbabwe  Midlands Province
# 2111408                  ZW              Zimbabwe  Midlands Province
# 2111409                  ZW              Zimbabwe  Midlands Province
# 2111410                  ZW              Zimbabwe  Midlands Province
# 2111411                  ZW              Zimbabwe  Midlands Province
#
#         sub_region_2 metro_area iso_3166_2_code  census_fips_code        date  \
# 0                NaN        NaN             NaN               NaN  2020-02-15
# 1                NaN        NaN             NaN               NaN  2020-02-16
# 2                NaN        NaN             NaN               NaN  2020-02-17
# 3                NaN        NaN             NaN               NaN  2020-02-18
# 4                NaN        NaN             NaN               NaN  2020-02-19
# ...              ...        ...             ...               ...         ...
# 2111407       Kwekwe        NaN             NaN               NaN  2020-08-19
# 2111408       Kwekwe        NaN             NaN               NaN  2020-08-20
# 2111409       Kwekwe        NaN             NaN               NaN  2020-08-21
# 2111410       Kwekwe        NaN             NaN               NaN  2020-08-24
# 2111411       Kwekwe        NaN             NaN               NaN  2020-08-25
#
#          retail_and_recreation_percent_change_from_baseline  \
# 0                                                      0.0
# 1                                                      1.0
# 2                                                     -1.0
# 3                                                     -2.0
# 4                                                     -2.0
# ...                                                    ...
# 2111407                                                NaN
# 2111408                                                NaN
# 2111409                                                NaN
# 2111410                                                NaN
# 2111411                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                      4.0
# 1                                                      4.0
# 2                                                      1.0
# 3                                                      1.0
# 4                                                      0.0
# ...                                                    ...
# 2111407                                                NaN
# 2111408                                                NaN
# 2111409                                                NaN
# 2111410                                                NaN
# 2111411                                                NaN
#
#          parks_percent_change_from_baseline  \
# 0                                       5.0
# 1                                       4.0
# 2                                       5.0
# 3                                       5.0
# 4                                       4.0
# ...                                     ...
# 2111407                                 NaN
# 2111408                                 NaN
# 2111409                                 NaN
# 2111410                                 NaN
# 2111411                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  0.0
# 4                                                 -1.0
# ...                                                ...
# 2111407                                            NaN
# 2111408                                            NaN
# 2111409                                            NaN
# 2111410                                            NaN
# 2111411                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 0                                            2.0
# 1                                            2.0
# 2                                            2.0
# 3                                            2.0
# 4                                            2.0
# ...                                          ...
# 2111407                                     -9.0
# 2111408                                     -5.0
# 2111409                                     -5.0
# 2111410                                     -4.0
# 2111411                                      7.0
#
#          residential_percent_change_from_baseline
# 0                                             1.0
# 1                                             1.0
# 2                                             1.0
# 3                                             1.0
# 4                                             1.0
# ...                                           ...
# 2111407                                       NaN
# 2111408                                       NaN
# 2111409                                       NaN
# 2111410                                       NaN
# 2111411                                       NaN
#
# [2111412 rows x 14 columns]

# %% [markdown]
# # Interventions

# %%
interventions = pd.read_csv("interventions.csv")
interventions
# Out:
#    lang    1st case   1st death School closure Public events banned  \
# 0    fr  2020-01-24  2020-02-14     2020-03-14           2020-03-13
# 1    da  2020-02-27  2020-03-12     2020-03-13           2020-03-12
# 2    de  2020-01-27  2020-03-09     2020-03-14           2020-03-22
# 3    it  2020-01-31  2020-02-22     2020-03-05           2020-03-09
# 4    nl  2020-02-27  2020-03-06     2020-03-11           2020-03-24
# 5    no  2020-02-26  2020-02-26     2020-03-13           2020-03-12
# 6    sr  2020-03-06  2020-03-20     2020-03-15           2020-03-21
# 7    sv  2020-01-31  2020-03-11     2020-03-18           2020-03-12
# 8    ko  2020-01-20  2020-02-20     2020-02-23                  NaN
# 9    ca  2020-01-31  2020-02-13     2020-03-12           2020-03-08
# 10   fi  2020-01-29  2020-03-21     2020-03-16           2020-03-16
# 11   ja  2020-01-16  2020-02-13     2020-02-27           2020-02-25
# 12   en         NaN         NaN            NaN                  NaN
#
#       Lockdown    Mobility    Normalcy
# 0   2020-03-17  2020-03-16  2020-07-02
# 1   2020-03-18  2020-03-11  2020-06-05
# 2   2020-03-22  2020-03-16  2020-07-10
# 3   2020-03-11  2020-03-11  2020-06-26
# 4          NaN  2020-03-16  2020-05-29
# 5   2020-03-24  2020-03-11  2020-06-04
# 6   2020-03-21  2020-03-16  2020-05-02
# 7          NaN  2020-03-11  2020-06-05
# 8          NaN  2020-02-25  2020-04-15
# 9   2020-03-14  2020-03-16         NaN
# 10         NaN  2020-03-16  2020-05-21
# 11         NaN  2020-03-31  2020-06-14
# 12         NaN  2020-03-16  2020-05-21

# %% [markdown]
# # Topics

# %%
topics_linked = pd.read_csv("topics_linked.csv.xz")
topics_linked
# Out:
#                             index  Geography.Regions.Asia.Central Asia  \
# 0                        Rosmalen                                False
# 1                    Commelinales                                False
# 2           Transport_in_Honduras                                False
# 3                          QuakeC                                False
# 4                    Food_writing                                False
# ...                           ...                                  ...
# 4306121           Faimaala_Filipo                                False
# 4306122            Jonathan_Horne                                False
# 4306123           Steven_Da_Costa                                False
# 4306124  The_Silence_of_Dr._Evans                                False
# 4306125                  Qiao_Jie                                False
#
#          Geography.Regions.Europe.Eastern Europe  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 4306121                                    False
# 4306122                                    False
# 4306123                                    False
# 4306124                                     True
# 4306125                                    False
#
#          History and Society.Military and warfare  Culture.Media.Television  \
# 0                                           False                     False
# 1                                           False                     False
# 2                                           False                     False
# 3                                           False                     False
# 4                                           False                     False
# ...                                           ...                       ...
# 4306121                                     False                     False
# 4306122                                     False                     False
# 4306123                                     False                     False
# 4306124                                      True                     False
# 4306125                                     False                     False
#
#          History and Society.Education  Culture.Media.Books  \
# 0                                False                False
# 1                                False                False
# 2                                False                False
# 3                                False                False
# 4                                False                False
# ...                                ...                  ...
# 4306121                          False                False
# 4306122                          False                False
# 4306123                          False                False
# 4306124                          False                False
# 4306125                          False                False
#
#          Geography.Regions.Africa.Africa*  Culture.Visual arts.Architecture  \
# 0                                   False                             False
# 1                                   False                             False
# 2                                   False                             False
# 3                                   False                             False
# 4                                   False                             False
# ...                                   ...                               ...
# 4306121                             False                             False
# 4306122                             False                             False
# 4306123                             False                             False
# 4306124                             False                             False
# 4306125                             False                             False
#
#          Culture.Biography.Women  ...  Geography.Regions.Asia.West Asia  \
# 0                          False  ...                             False
# 1                          False  ...                             False
# 2                          False  ...                             False
# 3                          False  ...                             False
# 4                          False  ...                             False
# ...                          ...  ...                               ...
# 4306121                     True  ...                             False
# 4306122                    False  ...                             False
# 4306123                    False  ...                             False
# 4306124                    False  ...                             False
# 4306125                     True  ...                             False
#
#          STEM.Chemistry  Geography.Regions.Europe.Northern Europe  \
# 0                 False                                     False
# 1                 False                                     False
# 2                 False                                     False
# 3                 False                                     False
# 4                 False                                     False
# ...                 ...                                       ...
# 4306121           False                                     False
# 4306122           False                                     False
# 4306123           False                                     False
# 4306124           False                                     False
# 4306125           False                                     False
#
#          Culture.Media.Video games  Geography.Regions.Asia.Southeast Asia  \
# 0                            False                                  False
# 1                            False                                  False
# 2                            False                                  False
# 3                            False                                  False
# 4                            False                                  False
# ...                            ...                                    ...
# 4306121                      False                                  False
# 4306122                      False                                  False
# 4306123                      False                                  False
# 4306124                      False                                  False
# 4306125                      False                                  False
#
#          Culture.Media.Entertainment  Culture.Media.Music  \
# 0                              False                False
# 1                              False                False
# 2                              False                False
# 3                              False                False
# 4                              False                False
# ...                              ...                  ...
# 4306121                        False                False
# 4306122                        False                False
# 4306123                        False                False
# 4306124                        False                False
# 4306125                        False                False
#
#          Geography.Regions.Asia.Asia*  Geography.Regions.Asia.North Asia  \
# 0                               False                              False
# 1                               False                              False
# 2                               False                              False
# 3                               False                              False
# 4                               False                              False
# ...                               ...                                ...
# 4306121                         False                              False
# 4306122                         False                              False
# 4306123                         False                              False
# 4306124                          True                              False
# 4306125                          True                              False
#
#                qid
# 0         Q2001490
# 1          Q290349
# 2         Q1130638
# 3         Q2122062
# 4         Q5465542
# ...            ...
# 4306121  Q84090991
# 4306122   Q1666264
# 4306123  Q22921600
# 4306124   Q4301095
# 4306125  Q84348042
#
# [4306126 rows x 66 columns]
